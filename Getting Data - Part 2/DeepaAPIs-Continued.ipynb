# %%
import pandas as pd
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
import requests

# %%
import json

# %%
my_key = 'eyJhbGciOiJIUzI1NiJ9.eyJhIjoiYWNfNjYxeHg4NDUiLCJqdGkiOiIyMzM4ZTRiMiJ9.XtRS2IDkBr2ebsW_BvAyj6f6NmifiFBvrWFE_qoWfkA'

# %%
common_crime = 'crime-incidents/'

# %%
#create a base url to call (this should end at '/observations?')

base = 'https://gcp-us-east1.api.carto.com'

# %%
#reconstruct the example URL, using your API key and series_id


crime_url = base + 'series_id=' + common_crime\
+ '&' + 'api_key=' + my_key + '&' + 'file_type=json'

# %%
#show your url
crime_url
# Out:
# 'https://gcp-us-east1.api.carto.comseries_id=crime-incidents/&api_key=eyJhbGciOiJIUzI1NiJ9.eyJhIjoiYWNfNjYxeHg4NDUiLCJqdGkiOiIyMzM4ZTRiMiJ9.XtRS2IDkBr2ebsW_BvAyj6f6NmifiFBvrWFE_qoWfkA&file_type=json'

# %%
#call the API to pull in the data

response = requests.get("https://phl.carto.com/api/v2/sql?q=SELECT * FROM incidents_part1_part2 WHERE dispatch_date_time >= '2019-01-01'")

# %%
#load the response's content

content = response.content

# %%
#load the content into JSON

loaded = json.loads(content)

# %%
#explore the JSON to see what the data looks like

loaded
# Out:
# {'rows': [{'cartodb_id': 2,
#    'the_geom': '0101000020E6100000A51C8299A5C752C006342AD3DCFF4340',
#    'the_geom_webmercator': '0101000020110F0000F80DE2A145E65FC1E5EC7592BE8F5241',
#    'objectid': 114,
#    'dc_dist': '25',
#    'psa': '3',
#    'dispatch_date_time': '2023-03-11T17:12:00Z',
#    'dispatch_date': '2023-03-11',
#    'dispatch_time': '12:12:00',
#    'hour': 12,
#    'dc_key': 202325014482,
#    'location_block': '3300 BLOCK HARTVILLE ST',
#    'ucr_general': '300',
#    'text_general_code': 'Robbery No Firearm',
#    'point_x': -75.1194824,
#    'point_y': 39.99892654},
#   {'cartodb_id': 4,
#    'the_geom': '0101000020E6100000F9245E3B64CC52C0B7195D940FF64340',
#    'the_geom_webmercator': '0101000020110F00000426B7CE54EE5FC1C5E06D37E2845241',
#    'objectid': 116,
#    'dc_dist': '01',
#    'psa': '1',
#    'dispatch_date_time': '2023-03-11T18:31:00Z',
#    'dispatch_date': '2023-03-11',
#    'dispatch_time': '13:31:00',
#    'hour': 13,
#    'dc_key': 202301004597,
# ...
